# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import re

# Funzione per ordinare i file in base alla temperatura e alla dimensione del lattice
def sort_files(file_pattern):
    files = glob.glob(file_pattern)
    
    def sort_key(filename):
        match = re.search(r'T(\d+(\.\d+)?)_N(\d+)', filename)
        if match:
            temp = float(match.group(1))
            size = int(match.group(3))
            return (temp, size)
        return (0, 0)  # Valore di default nel caso in cui il pattern non corrisponda
    
    files.sort(key=sort_key)
    return files

# Funzione per leggere i dati dai file
def read_data(files):
    data = {}
    
    for file in files:
        # Estrazione di temperatura e dimensione dal nome del file
        match = re.search(r'T(\d+(\.\d+)?)_N(\d+)', file)
        if match:
            temp = float(match.group(1))
            size = int(match.group(3))
            key = f'T{temp}_N{size}'
            
            if key not in data:
                data[key] = {'steps': [], 'energies': [], 'magnetizations': []}
            
            with open(file, 'r') as f:
                for line in f:
                    parts = line.split()
                    method, step, energy, magnetization = parts[0], int(parts[1]), float(parts[2]), float(parts[3])
                    data[key]['steps'].append(step)
                    data[key]['energies'].append(energy)
                    data[key]['magnetizations'].append(magnetization)
    
    return data

# Funzione per visualizzare i dati
def plot_data(data):
    for key in data:
        temp, size = key.split('_')
        temp = temp[1:]
        size = size[1:]
        
        plt.figure(figsize=(8, 8))
        
        plt.subplot(2, 1, 1)
        #plt.plot(data[key]['steps'], data[key]['energies'], label='Metropolis', color='b')
        plt.plot(data[key]['steps'], data[key]['energies'], label='Glauber', color='r')
        plt.title(f'Energy vs Steps (T={temp}, N={size})')
        plt.xlabel('Steps')
        plt.ylabel('Energy')
        plt.legend()
        
        plt.subplot(2, 1, 2)
        #plt.plot(data[key]['steps'], data[key]['magnetizations'], label='Metropolis', color='b')
        plt.plot(data[key]['steps'], data[key]['magnetizations'], label='Glauber', color='r')
        plt.title(f'Magnetization vs Steps (T={temp}, N={size})')
        plt.xlabel('Steps')
        #plt.xlim(-1,10000)
        plt.ylabel('Magnetization')
        plt.legend()
        
        plt.tight_layout()
        plt.show()

# Main script
sorted_files = sort_files('dati_file_txt/ising_data_T*.txt')
data = read_data(sorted_files)

plot_data(data)

# %%
# import numpy as np

# Funzione per determinare il tempo di equilibrio
def find_equilibrium_step(magnetizations, tolerance=0.01, window=1):
    """
    Trova il primo passo dove la variazione di magnetizzazione è minore di 'tolerance'
    per 'window' passi consecutivi.

    :param magnetizations: Lista delle magnetizzazioni ad ogni step
    :param tolerance: Soglia per la variazione di magnetizzazione (default=0.01)
    :param window: Numero di passi consecutivi richiesti per stabilità (default=10)
    :return: Step in cui viene raggiunto l'equilibrio, oppure -1 se non trovato
    """
    for i in range(len(magnetizations) - window):
        stable = True
        for j in range(window - 1):
            if abs(magnetizations[i + j + 1] - magnetizations[i + j]) > tolerance:
                stable = False
                break
        if stable:
            return i + window  # Restituisce lo step dopo il periodo stabile
    return -1  # Se non si trova un equilibrio, restituisce -1

# Esempio di utilizzo nel contesto del main script
def analyze_equilibrium(data):
    equilibrium_steps = {}
    
    for key, values in data.items():
        metropolis_eq_step = find_equilibrium_step(values['magnetizations']*1000, tolerance=0.0001, window=10)
        glauber_eq_step = find_equilibrium_step(values['magnetizations'], tolerance=0.000001, window=10)
        equilibrium_steps[key] = {'Metropolis': metropolis_eq_step, 'Glauber': glauber_eq_step}
    
    return equilibrium_steps


equilibrium_steps = analyze_equilibrium(data)

# %%
import pandas as pd

# Creazione del DataFrame con i risultati dell'equilibrio
def equilibrium_to_dataframe(equilibrium_steps):
    # Creiamo una lista di dizionari per ogni combinazione
    data = []
    for key, steps in equilibrium_steps.items():
        temp, size = key.split('_')
        temp = temp[1:]  # Rimuoviamo la 'T' da 'T1.0'
        size = size[1:]  # Rimuoviamo la 'N' da 'N25'
        
        data.append({
            'Temperature': float(temp),
            'Lattice Size': int(size),
            'Metropolis Equilibrium Step': steps['Metropolis'],
            'Glauber Equilibrium Step': steps['Glauber']
        })
    
    # Convertiamo la lista di dizionari in un DataFrame
    df = pd.DataFrame(data)
    return df

# %%
# Creiamo il DataFrame dai risultati dell'equilibrio
equilibrium_df = equilibrium_to_dataframe(equilibrium_steps)

# Mostriamo il DataFrame
equilibrium_df
# Out:
#    Temperature  Lattice Size  Metropolis Equilibrium Step  \
# 0          1.0            25                         1893
# 1          1.0            50                         1716
# 2          1.0           100                          304
# 3          2.5            25                          985
# 4          2.5            50                         2851
# 5          2.5           100                         2584
# 6          3.5            25                         3072
# 7          3.5            50                         3594
# 8          3.5           100                         8480
#
#    Glauber Equilibrium Step
# 0                      1893
# 1                      1716
# 2                       304
# 3                       985
# 4                      2851
# 5                      2584
# 6                      3072
# 7                      3594
# 8                      8480
